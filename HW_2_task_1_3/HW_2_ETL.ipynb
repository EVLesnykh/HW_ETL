# %%
# Подключаем библиотеки
import pandas as pd

# %% [markdown]
# **Задание 1.** <br>
# Скачайте датасет fifаs2.сsv. Проанализируйте его и определите, какие данные являются неполными. Удалите
# ненужные колонки и недостающие значения.

# %% [markdown]
# **Решение:**<br>

# %%
df = pd.read_csv('/content/drive/MyDrive/ETL/fifa_s2.csv', sep = ',')
df.head()
# Out:
#       ID       Name  Age  Nationality  Overall  Potential  \
# 0   1179  G. Buffon   40        Italy       88         88
# 1   5479   Casillas   37        Spain       82         82
# 2   8205      Braga   35     Portugal       70         70
# 3   9014  A. Robben   34  Netherlands       84         84
# 4  19521  J. Ibehre   35      England       61         61
#
#                   Club    Value  Wage Preferred Foot  \
# 0  Paris Saint-Germain   4000.0    77          Right
# 1             FC Porto   1500.0    10           Left
# 2              CD Aves    750.0     5          Right
# 3    FC Bayern München  15500.0   110           Left
# 4     Cambridge United    120.0     2          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       4.0          1.0       GK    2018
# 1                       4.0          1.0      NaN    2015
# 2                       1.0          3.0      LCM    2017
# ...

# %%
df.shape
# Out:
# (2399, 18)

# %% [markdown]
# Наименование полей:
# - ID — идентификационный номер футболиста
# - Name — имя
# - Age — возраст
# - Nationality — национальность
# - Overall — в целом
# - Potential — потенциал игрока (насколько высокого уровня он может достичь)
# - Club — клуб футболиста
# - Value — значение в евро
# - Wage — заработная плата
# - Preferred Foot — предпочтительная нога
# - International Reputation — международный рейтинг
# - Skill Moves — владение навыками
# - Position — позиция игрока на поле
# - Joined — год вступления в клуб
# - Contract Valid Until — дата окончания контракта
# - Height — рост игрока
# - Weight — вес игрока
# - Release Clause — освобождение от обязательств по контракту (отступные)

# %% [markdown]
# **Первичный анализ данных**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2399 entries, 0 to 2398
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        2399 non-null   int64
#  1   Name                      2399 non-null   object
#  2   Age                       2399 non-null   int64
#  3   Nationality               2392 non-null   object
#  4   Overall                   2399 non-null   int64
#  5   Potential                 2399 non-null   int64
#  6   Club                      2158 non-null   object
#  7   Value                     2142 non-null   float64
#  8   Wage                      2399 non-null   int64
#  9   Preferred Foot            2399 non-null   object
#  10  International Reputation  2389 non-null   float64
#  11  Skill Moves               2393 non-null   float64
#  12  Position                  2378 non-null   object
# ...

# %%
df.isna().sum() # проверим наличие пустых значений в DataFrame
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   7
# Overall                       0
# Potential                     0
# Club                        241
# Value                       257
# Wage                          0
# Preferred Foot                0
# International Reputation     10
# Skill Moves                   6
# Position                     21
# Joined                        0
# Contract Valid Until        273
# Height                        0
# Weight                        0
# Release Clause                3
# dtype: int64

# %% [markdown]
# **Вывод №1**. Представленные данные представляют таблицу, состояющую из 2399 строк и 18 столбцов.<br> Типы данных в таблице: float64(6), int64(6), object(6). <br> Пропущенные ячейки в таблице есть, в следующих столбцах:
# 1. Nationality - 7 ячеек
# 2. Club - 241 ячейка
# 3. Value - 257 ячеек
# 4. International Reputation - 10 ячеек
# 5. Skill Moves - 6 ячеек
# 6. Position - 21 ячейка
# 7. Contract Valid Until - 273 ячейки
# 8. Release Clause - 3 ячейки.

# %%
df.describe() # основные статистические характеристики данных по каждому числовому признаку
# Out:
#                   ID          Age      Overall    Potential          Value  \
# count    2399.000000  2399.000000  2399.000000  2399.000000    2142.000000
# mean   212033.680700    25.213005    69.115048    74.115048    5980.873016
# std     30549.399068     4.633622     8.060195     7.190957   11963.420681
# min      1179.000000    16.000000    47.000000    48.000000      20.000000
# 25%    195105.000000    22.000000    64.000000    69.000000     500.000000
# 50%    218745.000000    25.000000    69.000000    74.000000    1100.000000
# 75%    234576.000000    29.000000    74.000000    79.000000    6000.000000
# max    246608.000000    44.000000    94.000000    95.000000  118500.000000
#
#               Wage  International Reputation  Skill Moves       Joined  \
# count  2399.000000               2389.000000  2393.000000  2399.000000
# mean     24.178825                  1.308497     2.469703  2016.145894
# std      49.552098                  0.687175     0.844531     2.085829
# ...

# %% [markdown]
# **Вывод №2**. Согласно полученным статистическим характеристикам средние значения по игрокам следующие:<br>
# - Age - 25 лет
# - Overall - 69
# - Potential -74
# - Value - 5980
# - Wage - 24
# - International Reputation - 1
# - Skill Moves - 2
# - Joined - 2016
# - Height - 5,95 футов
# - Weight - 166,8 фунтов
# - Release Clause -10 690
# Но согласно полученным общим статистическим характеристикам по игрокам, видно, что значения в столбцах, Value, Wage, Release Clause (50% сильно отличаются от mean) являются ненормальными.

# %% [markdown]
# **Выполним очистку данных**

# %%
# Нулевые качественные значения NaN в столбцах заменим на строку 'none'
df[['Position', 'Nationality', 'Club', 'Contract Valid Until']] = df[['Position', 'Nationality', 'Club', 'Contract Valid Until']]. fillna('none')

# Количественные значения равные 0 (241), заполним mean значением
df['Wage'].replace(0,df['Wage'].mean(),inplace=True)

# Нулевые количественные значения NaN(257) в столбце Value заменим на значение mean
df['Value'] = df['Value']. fillna(df['Value'].mean())
df[['Release Clause']] = df[['Release Clause']]. fillna (35)

# Нулевые количественные значения NaN в столбцах заменим на значение min 1
df[['Skill Moves', 'International Reputation',]] = df[['Skill Moves', 'International Reputation']]. fillna (1)

# %%
df.isna().sum() # проверим наличие пустых значений в DataFrame после очистки данных
# Out:
# ID                          0
# Name                        0
# Age                         0
# Nationality                 0
# Overall                     0
# Potential                   0
# Club                        0
# Value                       0
# Wage                        0
# Preferred Foot              0
# International Reputation    0
# Skill Moves                 0
# Position                    0
# Joined                      0
# Contract Valid Until        0
# Height                      0
# Weight                      0
# Release Clause              0
# dtype: int64

# %% [markdown]
# **Удалим не значимые столбцы в DataFrame**

# %%
df = df.drop(['Joined','Contract Valid Until'],axis='columns')               # Удалить нерелевантные столбцы
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2399 entries, 0 to 2398
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        2399 non-null   int64
#  1   Name                      2399 non-null   object
#  2   Age                       2399 non-null   int64
#  3   Nationality               2399 non-null   object
#  4   Overall                   2399 non-null   int64
#  5   Potential                 2399 non-null   int64
#  6   Club                      2399 non-null   object
#  7   Value                     2399 non-null   float64
#  8   Wage                      2399 non-null   float64
#  9   Preferred Foot            2399 non-null   object
#  10  International Reputation  2399 non-null   float64
#  11  Skill Moves               2399 non-null   float64
#  12  Position                  2399 non-null   object
# ...

# %% [markdown]
# **Задание 2.** <br>
# Найдите в датафрейме полные дубликаты и удалите их. Значения могут быть одинаковыми, но написаны по-разному. Например, может отличаться размер регистра (заглавные и строчные буквы). Особое внимание уделить колонке с названиями команд.

# %% [markdown]
# **Решение:**<br>

# %%
# Приведем строковые значения столбцов в нижний регистр
df['Name'] = df['Name'].str.lower()
df['Nationality'] = df['Nationality'].str.lower()
df['Club'] = df['Club'].str.lower()
df['Preferred Foot'] = df['Preferred Foot'].str.lower()
df['Position'] = df['Position'].str.lower()
df
# Out:
#           ID           Name  Age  Nationality  Overall  Potential  \
# 0       1179      g. buffon   40        italy       88         88
# 1       5479       casillas   37        spain       82         82
# 2       8205          braga   35     portugal       70         70
# 3       9014      a. robben   34  netherlands       84         84
# 4      19521      j. ibehre   35      england       61         61
# ...      ...            ...  ...          ...      ...        ...
# 2394  246465       guerrero   16        spain       63         76
# 2395  246594    h. massengo   16       france       62         75
# 2396  246599  guillem jaime   19        spain       64         80
# 2397  246606    fran garcía   18        spain       64         79
# 2398  246608        fidalgo   21        spain       65         75
#
#                      Club    Value   Wage Preferred Foot  \
# 0     paris saint-germain   4000.0   77.0          right
# ...

# %% [markdown]
# В названиях клубов имеются значения (1.), пробелы, пропуски, преходы.

# %%
# Удаляем пробелы и переходы на новую строку.
df['Name'] = df['Name'].str.replace('\n', '')
df['Name'] = df['Name'].str.replace('\t', ' ')
df['Name'] = df['Name'].str.replace(' {2,}', ' ', regex=True)
df['Name'] = df['Name'].str.strip()

df['Club'] = df['Club'].str.replace('1.', '', regex=True) # удаляем (1.) в названиях клубов
df['Club'] = df['Club'].str.replace('\n', '')
df['Club'] = df['Club'].str.replace('\t', ' ')
df['Club'] = df['Club'].str.replace(' {2,}', ' ', regex=True)
df['Club'] = df['Club'].str.strip()
df

# %%
df.nunique() # количество уникальных наименований
# Out:
# ID                          2395
# Name                        2371
# Age                           27
# Nationality                  103
# Overall                       47
# Potential                     44
# Club                          79
# Value                        206
# Wage                         141
# Preferred Foot                 2
# International Reputation       5
# Skill Moves                    5
# Position                      28
# Height                        18
# Weight                        43
# Release Clause               715
# dtype: int64

# %% [markdown]
# **Найдем полные дубликаты**

# %% [markdown]
# **1. Проверим столбец 'ID', так как  из 2399 строк 2395 уникальны**

# %%
df[df.ID.duplicated()]
# Out:
#           ID        Name  Age Nationality  Overall  Potential  \
# 154   168651  i. rakitić   30     croatia       87         87
# 304   181872    a. vidal   31       chile       85         85
# 687   200466   v. eicher   27     germany       67         69
# 2123  241736  y. bisseck   17     germany       61         82
#
#                   Club    Value   Wage Preferred Foot  \
# 154       fc barcelona  46500.0  260.0          right
# 304       fc barcelona  26000.0  205.0          right
# 687   fc heidenheim 46    625.0    4.0           left
# 2123           fc köln    500.0    1.0          right
#
#       International Reputation  Skill Moves Position    Height  Weight  \
# 154                        4.0          3.0      rcm  6.000000   172.0
# 304                        4.0          3.0      cam  5.916667   165.0
# 687                        1.0          1.0       gk  6.250000   187.0
# 2123                       1.0          2.0       cb  6.333333   183.0
#
# ...

# %%
df[df['ID'] == 168651] # проверка дубликата
# Out:
#          ID        Name  Age Nationality  Overall  Potential          Club  \
# 153  168651  i. rakitić   30     croatia       87         87  fc barcelona
# 154  168651  i. rakitić   30     croatia       87         87  fc barcelona
#
#        Value   Wage Preferred Foot  International Reputation  Skill Moves  \
# 153  46500.0  260.0          right                       4.0          3.0
# 154  46500.0  260.0          right                       4.0          3.0
#
#     Position  Height  Weight  Release Clause
# 153      rcm     6.0   172.0         95300.0
# 154      rcm     6.0   172.0         95300.0

# %%
df[df['ID'] == 181872] # проверка дубликата
# Out:
#          ID      Name  Age Nationality  Overall  Potential          Club  \
# 303  181872  a. vidal   31       chile       85         85  fc barcelona
# 304  181872  a. vidal   31       chile       85         85  fc barcelona
#
#        Value   Wage Preferred Foot  International Reputation  Skill Moves  \
# 303  26000.0  205.0          right                       4.0          3.0
# 304  26000.0  205.0          right                       4.0          3.0
#
#     Position    Height  Weight  Release Clause
# 303      cam  5.916667   165.0         53300.0
# 304      cam  5.916667   165.0         53300.0

# %%
df[df['ID'] == 200466] # проверка дубликата
# Out:
#          ID       Name  Age Nationality  Overall  Potential              Club  \
# 686  200466  v. eicher   27     germany       67         69  fc heidenheim 46
# 687  200466  v. eicher   27     germany       67         69  fc heidenheim 46
#
#      Value  Wage Preferred Foot  International Reputation  Skill Moves  \
# 686  625.0   4.0           left                       1.0          1.0
# 687  625.0   4.0           left                       1.0          1.0
#
#     Position  Height  Weight  Release Clause
# 686       gk    6.25   187.0          1000.0
# 687       gk    6.25   187.0          1000.0

# %%
df[df['ID'] == 241736] # проверка дубликата
# Out:
#           ID        Name  Age Nationality  Overall  Potential     Club  Value  \
# 2122  241736  y. bisseck   17     germany       61         82  fc köln  500.0
# 2123  241736  y. bisseck   17     germany       61         82  fc köln  500.0
#
#       Wage Preferred Foot  International Reputation  Skill Moves Position  \
# 2122   1.0          right                       1.0          2.0       cb
# 2123   1.0          right                       1.0          2.0       cb
#
#         Height  Weight  Release Clause
# 2122  6.333333   183.0          1300.0
# 2123  6.333333   183.0          1300.0

# %% [markdown]
# **Вывод:** Как видно по столбцу 'ID' найдено 4 полных дубликата.

# %%
# Удалим полные дубликаты
df = df.drop_duplicates(subset=['ID'], keep='last')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2395 entries, 0 to 2398
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        2395 non-null   int64
#  1   Name                      2395 non-null   object
#  2   Age                       2395 non-null   int64
#  3   Nationality               2395 non-null   object
#  4   Overall                   2395 non-null   int64
#  5   Potential                 2395 non-null   int64
#  6   Club                      2395 non-null   object
#  7   Value                     2395 non-null   float64
#  8   Wage                      2395 non-null   float64
#  9   Preferred Foot            2395 non-null   object
#  10  International Reputation  2395 non-null   float64
#  11  Skill Moves               2395 non-null   float64
#  12  Position                  2395 non-null   object
# ...

# %%
df.ID.duplicated().sum() # проверим дубликаты по столбцу 'ID'
# Out:
# 0

# %% [markdown]
# **2. Проверим столбец 'Name', так как из 2395 строк 2371 уникальны**

# %%
df.nunique() # количество уникальных наименований
# Out:
# ID                          2395
# Name                        2371
# Age                           27
# Nationality                  103
# Overall                       47
# Potential                     44
# Club                          79
# Value                        206
# Wage                         141
# Preferred Foot                 2
# International Reputation       5
# Skill Moves                    5
# Position                      28
# Height                        18
# Weight                        43
# Release Clause               715
# dtype: int64

# %%
df[df.Name.duplicated()]
# Out:
#           ID           Name  Age Nationality  Overall  Potential  \
# 191   172680    s. sinclair   30     england       60         60
# 593   194730    juan carlos   30       spain       71         71
# 641   198710   j. rodríguez   26    colombia       88         89
# 719   201400        rafinha   25      brazil       82         87
# 783   203668  a. donnarumma   27       italy       75         75
# 857   206083      j. murphy   23     england       70         77
# 892   207863         felipe   29      brazil       83         83
# 1248  220540    d. bejarano   24     bolivia       63         66
# 1250  220605   j. rodríguez   22    colombia       66         76
# 1294  222368   a. miranchuk   22      russia       74         81
# 1441  225563     joão pedro   21      brazil       72         81
# 1461  225900   j. sambenito   26    paraguay       71         74
# 1556  229026   s. abdullahi   25     nigeria       72         75
# ...

# %%
# Проверка дубликатов
df[df['Name'] == 's. sinclair']
# Out:
#          ID         Name  Age Nationality  Overall  Potential            Club  \
# 156  169214  s. sinclair   29     england       75         75          celtic
# 191  172680  s. sinclair   30     england       60         60  bristol rovers
#
#       Value  Wage Preferred Foot  International Reputation  Skill Moves  \
# 156  6500.0  48.0          right                       2.0          4.0
# 191   190.0   2.0          right                       1.0          2.0
#
#     Position    Height  Weight  Release Clause
# 156       lm  5.833333   154.0         11700.0
# 191       cm  5.583333   148.0           333.0

# %% [markdown]
# **Вывод:** Как видно по столбцу 'Name' дубликаты показали одинаковые имена, но  разные ID, люди являются однофамильцами.

# %% [markdown]
# **Задание 3.** <br>
# Напишите функцию, которая добавит колонку с разбиением возраста по группам: до 20, от 20 до 30, от 30 до 36 и старше 36. Посчитайте количество футболистов в каждой категории.
# ЗАДАНИЕ НУЖНО СДЕЛАТЬ С ПОМОЧЬЮ APACHE SPARK КАК ПОКАЗАНО НА СЕМИНАРЕ. Соберите все в один pdf, код и скриншоты записанных таблиц с данными, скриншоты отработки лога спарка.

# %% [markdown]
# **Решение (ВАРИАНТ №1):**<br>

# %%
df.loc[df['Age']<=20, 'Age_category'] = 'before 20 years'
df.loc[df['Age'].between(20,30), 'Age_category'] = '20-30 years'
df.loc[df['Age'].between(30,36), 'Age_category'] = '30-36 years'
df.loc[df['Age']>36, 'Age_category'] = 'after 36 years'
df
# Out:
#           ID           Name  Age  Nationality  Overall  Potential  \
# 0       1179      g. buffon   40        italy       88         88
# 1       5479       casillas   37        spain       82         82
# 2       8205          braga   35     portugal       70         70
# 3       9014      a. robben   34  netherlands       84         84
# 4      19521      j. ibehre   35      england       61         61
# ...      ...            ...  ...          ...      ...        ...
# 2394  246465       guerrero   16        spain       63         76
# 2395  246594    h. massengo   16       france       62         75
# 2396  246599  guillem jaime   19        spain       64         80
# 2397  246606    fran garcía   18        spain       64         79
# 2398  246608        fidalgo   21        spain       65         75
#
#                      Club    Value   Wage Preferred Foot  \
# 0     paris saint-germain   4000.0   77.0          right
# ...

# %%
# Количество футболистов в каждой возрастной категории
df['Age_category'].value_counts()
# Out:
# 20-30 years        1645
# 30-36 years         466
# before 20 years     269
# after 36 years       15
# Name: Age_category, dtype: int64

# %% [markdown]
# **Решение (ВАРИАНТ №2) c помощью APACHE SPARK приложен в pdf**<br>
